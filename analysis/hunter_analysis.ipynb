# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
from transformers import AutoTokenizer, BertTokenizer, BertModel
import torch, re, json, jieba
from sklearn.cluster import KMeans, DBSCAN
import numpy as np
import matplotlib.pyplot as plt
from pyecharts.charts import Scatter
from pyecharts.charts import Bar
from pyecharts.charts import Geo
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType
from pyecharts.globals import ChartType
from pyecharts.charts import Pie
from pyecharts import options as opts
from pyecharts.faker import Faker
from sklearn.manifold import TSNE
from sklearn import preprocessing
import matplotlib as mpl
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
from analysis_utils import get_position_types

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
MODEL_PATH = '../models/model_zoo/medium'
# MODEL_PATH = '/home/vmice/projects/sbert-base-chinese-nli'
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# tokenizer = AutoTokenizer.from_pretrained(MODEL_PATH)
model = SentenceTransformer(MODEL_PATH, device=device)

test_sentences = ['我想要去加入一个经常旅游的团队，因为我喜欢旅游。',
                  '我们团队平时会偶尔去旅游的。',
                  '经常去旅游的团队我不喜欢去。']
# input_ = tokenizer(test_sentences, truncation=True, return_tensors="pt")
# input_
test_sentences = model.encode(test_sentences)
util.cos_sim(test_sentences, test_sentences)
# Out:
# No sentence-transformers model found with name ../models/model_zoo/medium. Creating a new one with MEAN pooling.
# Some weights of BertModel were not initialized from the model checkpoint at ../models/model_zoo/medium and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tensor([[1.0000, 0.6602, 0.3318],
#         [0.6602, 1.0000, 0.3214],
#         [0.3318, 0.3214, 1.0000]])

# %%
hunter_csv_file = '../datasets/result1-2.csv'

hunter_data = pd.read_csv(hunter_csv_file, encoding='GBK')
print('hunter data shape', hunter_data.shape)
# Out:
# hunter data shape (8690, 22)

# %%
hunter_data.iloc[1, :]
# Out:
# 序号                                                        2
# 求职者 ID                                  1579833809761861632
# 姓名                                                      李先生
# 性别                                                        男
# 年龄                                                     23.0
# 出生地                                                  广东省中山市
# 社会属性                                                     群众
# 工作经验                                                      无
# 期望岗位                                   ['数据分析师', '数据挖掘工程师']
# 期望薪资                                           [4000, 8000]
# 期望类型                                                     实习
# 期望城市                                              广东省深圳市南山区
# 期望行业                                                 ['不限']
# 预计到岗                                                   时间待议
# 工作经历                                 ['广东泰迪智能科技股份有限公司[助教]']
# 项目经历                                    ['银行客户忠诚度分析[数据分析]']
# 竞赛经历          ['泰迪杯[一等奖]', '其他[铜牌]', '其他[三等奖]', '泰迪杯[三等奖]']
# 教育经历                                                     []
# 培训经历                                                     []
# 技能类型      ['python[MASTER]', '数据分析[SKILLED]', '数据建模（机器学习...
# 语言类型                                                     []
# 证书类型                                     ['1+X中级数据分析师[其他]']
# Name: 1, dtype: object

# %% [markdown]
# ## 求职信息

# %% [markdown]
# ### 预期岗位

# %%
position_data_items_ = hunter_data['期望岗位'].unique().tolist()
position_data_items = []
for data_item in position_data_items_:
    position_data_items += eval(data_item)
position_data_dict = get_position_types(position_data_items)

position_counter = hunter_data['期望岗位'].value_counts()
position_counter_index = position_counter.index.to_list()
# position_counter_count_dict = {index: int(position_counter[index]) for index in position_counter_index}
position_counter_count_dict = {}
for position_index in position_counter_index:
    exp_type = eval(position_index)
    for position_name in exp_type:
        if position_name not in position_counter_count_dict: 
            position_counter_count_dict[position_name] = 0
        position_counter_count_dict[position_name] += int(position_counter[position_index])

# position_data_items
print(len(position_data_dict), len(position_counter_count_dict))
# Out:
# 9 9

# %%
social_pie = (
    Pie(init_opts=opts.InitOpts(width="800px", height="600px"))
    .add("", [list(z) for z in zip(list(position_counter_count_dict.keys()), 
                                   position_counter_count_dict.values())])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    .set_global_opts(
        toolbox_opts=opts.ToolboxOpts(is_show=True),
        title_opts={"text": ""}
    )
)
social_pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a69d5ec076964527b7f1a8d61d6f1434" style="width:800px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a69d5ec076964527b7f1a8d61d6f1434 = echarts.init(
#                     document.getElementById('a69d5ec076964527b7f1a8d61d6f1434'), 'white', {renderer: 'canvas'});
#                 var option_a69d5ec076964527b7f1a8d61d6f1434 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u6570\u636e\u5206\u6790\u5e08",
#                     "value": 8636
#                 },
#                 {
#                     "name": "\u6570\u636e\u6316\u6398\u5de5\u7a0b\u5e08",
#                     "value": 8589
#                 },
#                 {
#                     "name": "Hadoop\u5927\u6570\u636e\u5f00\u53d1\u5de5\u7a0b\u5e08",
#                     "value": 49
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u81ea\u7136\u8bed\u8a00\u5904\u7406\u5de5\u7a0b\u5e08",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u673a\u5668\u5b66\u4e60\u5de5\u7a0b\u5e08",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u7b97\u6cd5\u5de5\u7a0b\u5e08",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u56fe\u50cf\u5904\u7406\u5de5\u7a0b\u5e08",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u8ba1\u7b97\u673a\u89c6\u89c9\u5de5\u7a0b\u5e08",
#                     "value": 2
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6570\u636e\u5206\u6790\u5e08",
#                 "\u6570\u636e\u6316\u6398\u5de5\u7a0b\u5e08",
#                 "Hadoop\u5927\u6570\u636e\u5f00\u53d1\u5de5\u7a0b\u5e08",
#                 "\u5176\u4ed6",
#                 "\u81ea\u7136\u8bed\u8a00\u5904\u7406\u5de5\u7a0b\u5e08",
#                 "\u673a\u5668\u5b66\u4e60\u5de5\u7a0b\u5e08",
#                 "\u7b97\u6cd5\u5de5\u7a0b\u5e08",
#                 "\u56fe\u50cf\u5904\u7406\u5de5\u7a0b\u5e08",
#                 "\u8ba1\u7b97\u673a\u89c6\u89c9\u5de5\u7a0b\u5e08"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": {},
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",
#                     "\u5173\u95ed",
#                     "\u5237\u65b0"
#                 ],
#                 "backgroundColor": "#fff",
#                 "textareaColor": "#fff",
#                 "textareaBorderColor": "#333",
#                 "textColor": "#000",
#                 "buttonColor": "#c23531",
#                 "buttonTextColor": "#fff"
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u533a\u57df\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "icon": {},
#                 "filterMode": "filter"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u5207\u6362\u4e3a\u6298\u7ebf\u56fe",
#                     "bar": "\u5207\u6362\u4e3a\u67f1\u72b6\u56fe",
#                     "stack": "\u5207\u6362\u4e3a\u5806\u53e0",
#                     "tiled": "\u5207\u6362\u4e3a\u5e73\u94fa"
#                 },
#                 "icon": {}
#             }
#         }
#     }
# };
#                 chart_a69d5ec076964527b7f1a8d61d6f1434.setOption(option_a69d5ec076964527b7f1a8d61

# %% [markdown]
# ### 薪资需求

# %%
social_counter = hunter_data.loc[:, ['期望岗位', '期望薪资']]
social_counter_dict = {}
for idx in range(social_counter.shape[0]):
    exp_type = social_counter.iloc[idx].values[0]
    wage_count = social_counter.iloc[idx].values[1]
    for position_name in eval(exp_type):
        if position_name not in social_counter_dict: 
            social_counter_dict[position_name] = []
        social_counter_dict[position_name].append(np.mean(eval(wage_count)))

social_counter_dict = {position_name: np.round(np.mean(counts), 2) for position_name, counts in social_counter_dict.items()}
social_counter_dict
# Out:
# {'数据分析师': 5027.21,
#  '数据挖掘工程师': 5021.19,
#  '机器学习工程师': 7705.88,
#  '其他': 6469.7,
#  '自然语言处理工程师': 6454.55,
#  '算法工程师': 14428.57,
#  'Hadoop大数据开发工程师': 7132.65,
#  '图像处理工程师': 8285.71,
#  '计算机视觉工程师': 6750.0}

# %%
# position_data_dict, position_counter_count_dict
wage_bar = (
    Bar(init_opts=opts.InitOpts(width="800px", height="600px"))
    .add_xaxis(list(social_counter_dict.keys()))
    .add_yaxis('全部', list(social_counter_dict.values()))
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=20)),
        toolbox_opts=opts.ToolboxOpts(is_show=True),
        title_opts={"text": "平均薪资"})
)
wage_bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d452be04ea6e4dc19f12c5f1b29cc21b" style="width:800px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d452be04ea6e4dc19f12c5f1b29cc21b = echarts.init(
#                     document.getElementById('d452be04ea6e4dc19f12c5f1b29cc21b'), 'white', {renderer: 'canvas'});
#                 var option_d452be04ea6e4dc19f12c5f1b29cc21b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5168\u90e8",
#             "legendHoverLink": true,
#             "data": [
#                 5027.21,
#                 5021.19,
#                 7705.88,
#                 6469.7,
#                 6454.55,
#                 14428.57,
#                 7132.65,
#                 8285.71,
#                 6750.0
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5168\u90e8"
#             ],
#             "selected": {
#                 "\u5168\u90e8": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "rotate": 20,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6570\u636e\u5206\u6790\u5e08",
#                 "\u6570\u636e\u6316\u6398\u5de5\u7a0b\u5e08",
#                 "\u673a\u5668\u5b66\u4e60\u5de5\u7a0b\u5e08",
#                 "\u5176\u4ed6",
#                 "\u81ea\u7136\u8bed\u8a00\u5904\u7406\u5de5\u7a0b\u5e08",
#                 "\u7b97\u6cd5\u5de5\u7a0b\u5e08",
#                 "Hadoop\u5927\u6570\u636e\u5f00\u53d1\u5de5\u7a0b\u5e08",
#                 "\u56fe\u50cf\u5904\u7406\u5de5\u7a0b\u5e08",
#                 "\u8ba1\u7b97\u673a\u89c6\u89c9\u5de5\u7a0b\u5e08"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": {
#         "text": "\u5e73\u5747\u85aa\u8d44"
#     },
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",
#                     "\u5173\u95ed",
#                     "\u5237\u65b0"
#                 ],
#                 "backgroundColor": "#fff",
#                 "textareaColor": "#fff",
#                 "textareaBorderColor": "#333",
#                 "textColor": "#000",
#                 "buttonColor": "#c23531",
#                 "buttonTextColor": "#fff"
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u533a\u57df\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "icon": {},
#                 "filterMode": "filter"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u5207\u6362\u4e3a\u6298\u7ebf\u56fe",
#                     "bar": "\u5207\u6362\u4e3a\u67f1\u72b6\u56fe",
#                     "stack": "\u5207\u6362\u4e3a\u5806\u53e0",
#                     "tiled": "\u5207\u6362\u4e3a\u5e73\u94fa"
#                 },
#                 "icon": {}
#             }
#         }
#     }
# };
#                 chart_d452be04ea6e4dc19f12c5f1b29cc21b.setOption(option_d452be04ea6e4dc19f12c5f1b29cc21b);
#         });
#     </script>

# %% [markdown]
# ### 社会属性

# %%
social_counter = hunter_data.loc[:, ['社会属性']]
social_counter_dict = {}
for idx in range(social_counter.shape[0]):
    exp_type = social_counter.iloc[idx].values[0]
    # wage_count = social_counter.iloc[idx].values[1]
    if not isinstance(exp_type, str): continue
    if exp_type not in social_counter_dict: 
        social_counter_dict[exp_type] = 0
    social_counter_dict[exp_type] += 1

# social_counter_dict = {position_name: np.round(np.mean(counts), 2) for position_name, counts in social_counter_dict.items()}
social_counter_dict
# Out:
# {'共青团员': 110, '群众': 15, '党员': 18, '预备党员': 13}

# %%
social_pie = (
    Pie(init_opts=opts.InitOpts(width="800px", height="600px"))
    .add("", [list(z) for z in zip(list(social_counter_dict.keys()), 
                                   social_counter_dict.values())])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    .set_global_opts(
        toolbox_opts=opts.ToolboxOpts(is_show=True),
        title_opts={"text": ""}
    )
)
social_pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dfdf5d88500b41708f363d92ae9d1368" style="width:800px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dfdf5d88500b41708f363d92ae9d1368 = echarts.init(
#                     document.getElementById('dfdf5d88500b41708f363d92ae9d1368'), 'white', {renderer: 'canvas'});
#                 var option_dfdf5d88500b41708f363d92ae9d1368 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u5171\u9752\u56e2\u5458",
#                     "value": 110
#                 },
#                 {
#                     "name": "\u7fa4\u4f17",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u515a\u5458",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u9884\u5907\u515a\u5458",
#                     "value": 13
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5171\u9752\u56e2\u5458",
#                 "\u7fa4\u4f17",
#                 "\u515a\u5458",
#                 "\u9884\u5907\u515a\u5458"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": {},
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",
#                     "\u5173\u95ed",
#                     "\u5237\u65b0"
#                 ],
#                 "backgroundColor": "#fff",
#                 "textareaColor": "#fff",
#                 "textareaBorderColor": "#333",
#                 "textColor": "#000",
#                 "buttonColor": "#c23531",
#                 "buttonTextColor": "#fff"
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u533a\u57df\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "icon": {},
#                 "filterMode": "filter"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u5207\u6362\u4e3a\u6298\u7ebf\u56fe",
#                     "bar": "\u5207\u6362\u4e3a\u67f1\u72b6\u56fe",
#                     "stack": "\u5207\u6362\u4e3a\u5806\u53e0",
#                     "tiled": "\u5207\u6362\u4e3a\u5e73\u94fa"
#                 },
#                 "icon": {}
#             }
#         }
#     }
# };
#                 chart_dfdf5d88500b41708f363d92ae9d1368.setOption(option_dfdf5d88500b41708f363d92ae9d1368);
#         });
#     </script>

# %% [markdown]
# ### 工作经验

# %%
work_exp_counter = hunter_data.loc[:, ['工作经验']]
work_exp_counter_dict = {}
for idx in range(work_exp_counter.shape[0]):
    exp_type = work_exp_counter.iloc[idx].values[0]
    # wage_count = social_counter.iloc[idx].values[1]
    if not isinstance(exp_type, str): continue
    if exp_type not in work_exp_counter_dict: 
        work_exp_counter_dict[exp_type] = 0
    work_exp_counter_dict[exp_type] += 1

# social_counter_dict = {position_name: np.round(np.mean(counts), 2) for position_name, counts in social_counter_dict.items()}
work_exp_counter_dict
# Out:
# {'无': 133, '1年': 15, '4年': 4, '3年': 3, '10年以上': 1}

# %%
work_exp_pie = (
    Pie(init_opts=opts.InitOpts(width="800px", height="600px"))
    .add("", [list(z) for z in zip(list(work_exp_counter_dict.keys()), 
                                   work_exp_counter_dict.values())])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    .set_global_opts(
        toolbox_opts=opts.ToolboxOpts(is_show=True),
        title_opts={"text": ""}
    )
)
work_exp_pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e5e56f680bbd499aa67fadecb8c66c9d" style="width:800px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e5e56f680bbd499aa67fadecb8c66c9d = echarts.init(
#                     document.getElementById('e5e56f680bbd499aa67fadecb8c66c9d'), 'white', {renderer: 'canvas'});
#                 var option_e5e56f680bbd499aa67fadecb8c66c9d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u65e0",
#                     "value": 133
#                 },
#                 {
#                     "name": "1\u5e74",
#                     "value": 15
#                 },
#                 {
#                     "name": "4\u5e74",
#                     "value": 4
#                 },
#                 {
#                     "name": "3\u5e74",
#                     "value": 3
#                 },
#                 {
#                     "name": "10\u5e74\u4ee5\u4e0a",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u65e0",
#                 "1\u5e74",
#                 "4\u5e74",
#                 "3\u5e74",
#                 "10\u5e74\u4ee5\u4e0a"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": {},
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",
#                     "\u5173\u95ed",
#                     "\u5237\u65b0"
#                 ],
#                 "backgroundColor": "#fff",
#                 "textareaColor": "#fff",
#                 "textareaBorderColor": "#333",
#                 "textColor": "#000",
#                 "buttonColor": "#c23531",
#                 "buttonTextColor": "#fff"
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u533a\u57df\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "icon": {},
#                 "filterMode": "filter"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u5207\u6362\u4e3a\u6298\u7ebf\u56fe",
#                     "bar": "\u5207\u6362\u4e3a\u67f1\u72b6\u56fe",
#                     "stack": "\u5207\u6362\u4e3a\u5806\u53e0",
#                     "tiled": "\u5207\u6362\u4e3a\u5e73\u94fa"
#                 },
#                 "icon": {}
#             }
#         }
#     }
# };
#                 chart_e5e56f680bbd499aa67fadecb8c66c9d.setOption(option_e5e56f680bbd499aa67fadecb8c66c9d);
#         });
#     </script>

# %% [markdown]
# ### 期望类型

# %%
exp_counter = hunter_data.loc[:, ['期望类型']]
exp_counter_dict = {}
for idx in range(exp_counter.shape[0]):
    exp_type = exp_counter.iloc[idx].values[0]
    # wage_count = social_counter.iloc[idx].values[1]
    if not isinstance(exp_type, str): continue
    if exp_type not in exp_counter_dict: 
        exp_counter_dict[exp_type] = 0
    exp_counter_dict[exp_type] += 1

# social_counter_dict = {position_name: np.round(np.mean(counts), 2) for position_name, counts in social_counter_dict.items()}
exp_counter_dict
# Out:
# {'实习': 9, '全职': 138, '无': 9}

# %%
exp_pie = (
    Pie(init_opts=opts.InitOpts(width="800px", height="600px"))
    .add("", [list(z) for z in zip(list(exp_counter_dict.keys()), 
                                   exp_counter_dict.values())])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    .set_global_opts(
        toolbox_opts=opts.ToolboxOpts(is_show=True),
        title_opts={"text": ""}
    )
)
exp_pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5eed76fa1ca14c03aeb1b0e3cd93b14c" style="width:800px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5eed76fa1ca14c03aeb1b0e3cd93b14c = echarts.init(
#                     document.getElementById('5eed76fa1ca14c03aeb1b0e3cd93b14c'), 'white', {renderer: 'canvas'});
#                 var option_5eed76fa1ca14c03aeb1b0e3cd93b14c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u5b9e\u4e60",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u5168\u804c",
#                     "value": 138
#                 },
#                 {
#                     "name": "\u65e0",
#                     "value": 9
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5b9e\u4e60",
#                 "\u5168\u804c",
#                 "\u65e0"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": {},
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",
#                     "\u5173\u95ed",
#                     "\u5237\u65b0"
#                 ],
#                 "backgroundColor": "#fff",
#                 "textareaColor": "#fff",
#                 "textareaBorderColor": "#333",
#                 "textColor": "#000",
#                 "buttonColor": "#c23531",
#                 "buttonTextColor": "#fff"
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u533a\u57df\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "icon": {},
#                 "filterMode": "filter"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u5207\u6362\u4e3a\u6298\u7ebf\u56fe",
#                     "bar": "\u5207\u6362\u4e3a\u67f1\u72b6\u56fe",
#                     "stack": "\u5207\u6362\u4e3a\u5806\u53e0",
#                     "tiled": "\u5207\u6362\u4e3a\u5e73\u94fa"
#                 },
#                 "icon": {}
#             }
#         }
#     }
# };
#                 chart_5eed76fa1ca14c03aeb1b0e3cd93b14c.setOption(option_5eed76fa1ca14c03aeb1b0e3cd93b14c);
#         });
#     </script>

# %% [markdown]
# ### 期望行业

# %%
exp_counter = hunter_data.loc[:, ['期望行业']]
exp_counter_dict = {}
for idx in range(exp_counter.shape[0]):
    exp_types = eval(exp_counter.iloc[idx].values[0])
    # wage_count = social_counter.iloc[idx].values[1]
    for exp_type in exp_types:
        # if not isinstance(exp_type, str): continue
        if exp_type not in exp_counter_dict: 
            exp_counter_dict[exp_type] = 0
        exp_counter_dict[exp_type] += 1

exp_counter_dict
# Out:
# {'不限': 75,
#  '互联网': 8603,
#  '数据服务': 18,
#  '电子商务': 8,
#  '游戏': 10,
#  '计算机软件': 7,
#  'O2O': 2,
#  '媒体': 5,
#  '金融': 15,
#  '在线教育': 3,
#  '信息安全': 4,
#  '医疗健康': 1,
#  '通信设备': 1,
#  '人力资源服务': 1}

# %%
exp_pie = (
    Pie(init_opts=opts.InitOpts(width="800px", height="600px"))
    .add("", [list(z) for z in zip(list(exp_counter_dict.keys()), 
                                   exp_counter_dict.values())])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    .set_global_opts(
        toolbox_opts=opts.ToolboxOpts(is_show=True),
        title_opts={"text": ""}
    )
)
exp_pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="26fec75b9ccb4a02a3a4c1351843073d" style="width:800px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_26fec75b9ccb4a02a3a4c1351843073d = echarts.init(
#                     document.getElementById('26fec75b9ccb4a02a3a4c1351843073d'), 'white', {renderer: 'canvas'});
#                 var option_26fec75b9ccb4a02a3a4c1351843073d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u4e0d\u9650",
#                     "value": 75
#                 },
#                 {
#                     "name": "\u4e92\u8054\u7f51",
#                     "value": 8603
#                 },
#                 {
#                     "name": "\u6570\u636e\u670d\u52a1",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u7535\u5b50\u5546\u52a1",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u6e38\u620f",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u8ba1\u7b97\u673a\u8f6f\u4ef6",
#                     "value": 7
#                 },
#                 {
#                     "name": "O2O",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5a92\u4f53",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u91d1\u878d",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u5728\u7ebf\u6559\u80b2",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u4fe1\u606f\u5b89\u5168",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u533b\u7597\u5065\u5eb7",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u901a\u4fe1\u8bbe\u5907",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4eba\u529b\u8d44\u6e90\u670d\u52a1",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e0d\u9650",
#                 "\u4e92\u8054\u7f51",
#                 "\u6570\u636e\u670d\u52a1",
#                 "\u7535\u5b50\u5546\u52a1",
#                 "\u6e38\u620f",
#                 "\u8ba1\u7b97\u673a\u8f6f\u4ef6",
#                 "O2O",
#                 "\u5a92\u4f53",
#                 "\u91d1\u878d",
#                 "\u5728\u7ebf\u6559\u80b2",
#                 "\u4fe1\u606f\u5b89\u5168",
#                 "\u533b\u7597\u5065\u5eb7",
#                 "\u901a\u4fe1\u8bbe\u5907",
#                 "\u4eba\u529b\u8d44\u6e90\u670d\u52a1"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": {},
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",
#                     "\u5173\u95ed",
#                     "\u5237\u65b0"
#                 ],
#                 "backgroundColor": "#fff",
#                 "textareaColor": "#fff",
#                 "textareaBorderColor": "#333",
#                 "textColor": "#000",
#                 "buttonColor": "#c23531",
#                 "buttonTextColor": "#fff"
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u533a\u57df\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "icon": {},
#                 "filterMode": "filter"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],

# %% [markdown]
# ### 知识储备

# %%
exp_counter = hunter_data.loc[:, ['技能类型']]
exp_counter_dict = {}
for idx in range(exp_counter.shape[0]):
    exp_types = eval(exp_counter.iloc[idx].values[0])
    # wage_count = social_counter.iloc[idx].values[1]
    for exp_type in exp_types:
        # if not isinstance(exp_type, str): continue
        exp_type = re.sub(r'\[.*\]', '', exp_type).lower()
        if exp_type not in exp_counter_dict: 
            exp_counter_dict[exp_type] = 0
        exp_counter_dict[exp_type] += 1

len(exp_counter_dict)
# Out:
# 95

# %%
exp_pie = (
    Pie(init_opts=opts.InitOpts(width="1000px", height="600px"))
    .add("", [list(z) for z in zip(list(exp_counter_dict.keys()), 
                                   exp_counter_dict.values())])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    .set_global_opts(
        legend_opts=opts.LegendOpts(is_show=False),
        toolbox_opts=opts.ToolboxOpts(is_show=True),
        title_opts={"text": ""}
    )
)
exp_pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dcd6d1f2f405426ab4dd0b74e7fe300c" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dcd6d1f2f405426ab4dd0b74e7fe300c = echarts.init(
#                     document.getElementById('dcd6d1f2f405426ab4dd0b74e7fe300c'), 'white', {renderer: 'canvas'});
#                 var option_dcd6d1f2f405426ab4dd0b74e7fe300c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "python",
#                     "value": 585
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u6570\u636e\u5efa\u6a21\uff08\u673a\u5668\u5b66\u4e60\uff09",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u7f51\u7edc\u722c\u866b",
#                     "value": 1
#                 },
#                 {
#                     "name": "mysql",
#                     "value": 150
#                 },
#                 {
#                     "name": "linux",
#                     "value": 13
#                 },
#                 {
#                     "name": "hadoop",
#                     "value": 44
#                 },
#                 {
#                     "name": "spark",
#                     "value": 12
#                 },
#                 {
#                     "name": "sql",
#                     "value": 10
#                 },
#                 {
#                     "name": "spss",
#                     "value": 4
#                 },
#                 {
#                     "name": "excel",
#                     "value": 9
#                 },
#                 {
#                     "name": "c++",
#                     "value": 1
#                 },
#                 {
#                     "name": "matlab",
#                     "value": 1
#                 },
#                 {
#                     "name": "nlp",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u7f51\u9875\u722c\u866b",
#                     "value": 1
#                 },
#                 {
#                     "name": "c\u8bed\u8a00/c++",
#                     "value": 1
#                 },
#                 {
#                     "name": "spsspro",
#                     "value": 1
#                 },
#                 {
#                     "name": "office",
#                     "value": 8
#                 },
#                 {
#                     "name": "tableau",
#                     "value": 1
#                 },
#                 {
#                     "name": "python\u6280\u80fd",
#                     "value": 1
#                 },
#                 {
#                     "name": "stata",
#                     "value": 1
#                 },
#                 {
#                     "name": "eviews",
#                     "value": 1
#                 },
#                 {
#                     "name": "java",
#                     "value": 41
#                 },
#                 {
#                     "name": "r\u8bed\u8a00",
#                     "value": 3
#                 },
#                 {
#                     "name": "sql-server",
#                     "value": 1
#                 },
#                 {
#                     "name": "c",
#                     "value": 1
#                 },
#                 {
#                     "name": "ps",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u7f51\u9875\u8bbe\u8ba1",
#                     "value": 1
#                 },
#                 {
#                     "name": "html",
#                     "value": 1
#                 },
#                 {
#                     "name": "javascript",
#                     "value": 1
#                 },
#                 {
#                     "name": "css",
#                     "value": 1
#                 },
#                 {
#                     "name": "power bi",
#                     "value": 1
#                 },
#                 {
#                     "name": "sql sever",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6e38\u6cf3",
#                     "value": 1
#                 },
#                 {
#                     "name": "hive",
#                     "value": 6
#                 },
#                 {
#                     "name": "hbase",
#                     "value": 1
#                 },
#                 {
#                     "name": "c1\u9a7e\u7167",
#                     "value": 1
#                 },
#                 {
#                     "name": "tensorflow",
#                     "value": 5
#                 },
#                 {
#                     "name": "kafka",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u8001\u516b\u79d8\u5236\u5c0f\u6c49\u5821",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u626f\u9762",
#                     "value": 1
#                 },
#                 {
#                     "name": "saprk",
#                     "value": 1
#                 },
#                 {
#                     "name": "hdfs",
#                     "value": 30
#                 },
#                 {
#                     "name": "mapreduce",
#                     "value": 30
#                 },
#                 {
#                     "name": "numpy",
#                     "value": 188
#                 },
#                 {
#                     "name": "matplotlib",
#                     "value": 188
#                 },
#                 {
#                     "name": "pandas",
#                     "value": 188
#                 },
#                 {
#                     "name": "scikit-learn",
#                     "value": 188
#                 },
#                 {
#                     "name": "\u719f\u7ec3java \uff0cjava\u57fa\u7840\uff0cjavaweb",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u719f\u6089\u5927\u6570\u636e\u6280\u672f\u7ec4\u4ef6\uff0chadoop\uff0chive\uff0cspark",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u719f\u6089linux\u3001centos\u64cd\u4f5c\u7cfb\u7edf",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u719f\u6089sql\u8bed\u53e5\uff0cmysql\u6570\u636e\u5e93\u7ba1\u7406\u7cfb\u7edf",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5927\u5b66\u82f1\u8bed\u56db\u7ea7",

# %%
exp_counter = hunter_data.loc[:, ['语言类型']]
exp_counter_dict = {}
for idx in range(exp_counter.shape[0]):
    exp_types = eval(exp_counter.iloc[idx].values[0])
    # wage_count = social_counter.iloc[idx].values[1]
    for exp_type in exp_types:
        # if not isinstance(exp_type, str): continue
        exp_type = re.sub(r'\[.*\]', '', exp_type).lower()
        if exp_type not in exp_counter_dict: 
            exp_counter_dict[exp_type] = 0
        exp_counter_dict[exp_type] += 1

len(exp_counter_dict)
# Out:
# 32

# %%
exp_pie = (
    Pie(init_opts=opts.InitOpts(width="1000px", height="600px"))
    .add("", [list(z) for z in zip(list(exp_counter_dict.keys()), 
                                   exp_counter_dict.values())])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    .set_global_opts(
        legend_opts=opts.LegendOpts(is_show=False),
        toolbox_opts=opts.ToolboxOpts(is_show=True),
        title_opts={"text": ""}
    )
)
exp_pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4f56610ab32847d58d67b0a0f3d5981d" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4f56610ab32847d58d67b0a0f3d5981d = echarts.init(
#                     document.getElementById('4f56610ab32847d58d67b0a0f3d5981d'), 'white', {renderer: 'canvas'});
#                 var option_4f56610ab32847d58d67b0a0f3d5981d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "r",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u666e\u901a\u8bdd",
#                     "value": 16
#                 },
#                 {
#                     "name": "\u82f1\u8bed",
#                     "value": 30
#                 },
#                 {
#                     "name": "python",
#                     "value": 9
#                 },
#                 {
#                     "name": "mysql",
#                     "value": 3
#                 },
#                 {
#                     "name": "power bi",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u82f1\u8bed\u56db\u7ea7",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u7ca4\u8bed",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u82f1\u8bed\u516d\u7ea7",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6c49\u8bed",
#                     "value": 1
#                 },
#                 {
#                     "name": "java",
#                     "value": 9
#                 },
#                 {
#                     "name": "cet4",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u666e\u901a\u8bdd\u4e8c\u7ea7\u4e59\u7b49",
#                     "value": 1
#                 },
#                 {
#                     "name": "c",
#                     "value": 1
#                 },
#                 {
#                     "name": "matlab",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5927\u5b66\u82f1\u8bed\u56db\uff08cet-4\uff09",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u65e5\u8bed",
#                     "value": 2
#                 },
#                 {
#                     "name": "javascript",
#                     "value": 1
#                 },
#                 {
#                     "name": "css",
#                     "value": 1
#                 },
#                 {
#                     "name": "html",
#                     "value": 1
#                 },
#                 {
#                     "name": "sql\u7c7bsql",
#                     "value": 1
#                 },
#                 {
#                     "name": "scala",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u6f6e\u6c55\u8bdd",
#                     "value": 1
#                 },
#                 {
#                     "name": "cet-6",
#                     "value": 1
#                 },
#                 {
#                     "name": "sql server",
#                     "value": 1
#                 },
#                 {
#                     "name": "spss",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u666e\u901a\u8bdd\u4e8c\u7ea7",
#                     "value": 1
#                 },
#                 {
#                     "name": "sql",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u82f1\u8bed\uff08cet-4\uff09",
#                     "value": 1
#                 },
#                 {
#                     "name": "cet-4",
#                     "value": 1
#                 },
#                 {
#                     "name": "spark",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u666e\u901a\u8bdd\u4e8c\u7532",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "r",
#                 "\u666e\u901a\u8bdd",
#                 "\u82f1\u8bed",
#                 "python",
#                 "mysql",
#                 "power bi",
#                 "\u82f1\u8bed\u56db\u7ea7",
#                 "\u7ca4\u8bed",
#                 "\u82f1\u8bed\u516d\u7ea7",
#                 "\u6c49\u8bed",
#                 "java",
#                 "cet4",
#                 "\u666e\u901a\u8bdd\u4e8c\u7ea7\u4e59\u7b49",
#                 "c",
#                 "matlab",
#                 "\u5927\u5b66\u82f1\u8bed\u56db\uff08cet-4\uff09",
#                 "\u65e5\u8bed",
#                 "javascript",
#                 "css",
#                 "html",
#                 "sql\u7c7bsql",
#                 "scala",
#                 "\u6f6e\u6c55\u8bdd",
#                 "cet-6",
#                 "sql server",
#                 "spss",
#                 "\u666e\u901a\u8bdd\u4e8c\u7ea7",
#                 "sql",
#                 "\u82f1\u8bed\uff08cet-4\uff09",
#                 "cet-4",
#                 "spark",
#                 "\u666e\u901a\u8bdd\u4e8c\u7532"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animatio

# %%
exp_counter = hunter_data.loc[:, ['证书类型']]
exp_counter_dict = {}
for idx in range(exp_counter.shape[0]):
    exp_types = eval(exp_counter.iloc[idx].values[0])
    # wage_count = social_counter.iloc[idx].values[1]
    for exp_type in exp_types:
        # if not isinstance(exp_type, str): continue
        exp_type = re.sub(r'\[.*\]', '', exp_type).lower()
        if exp_type not in exp_counter_dict: 
            exp_counter_dict[exp_type] = 0
        exp_counter_dict[exp_type] += 1

len(exp_counter_dict)
# Out:
# 81

# %%
exp_pie = (
    Pie(init_opts=opts.InitOpts(width="1000px", height="600px"))
    .add("", [list(z) for z in zip(list(exp_counter_dict.keys()), 
                                   exp_counter_dict.values())])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    .set_global_opts(
        legend_opts=opts.LegendOpts(is_show=False),
        toolbox_opts=opts.ToolboxOpts(is_show=True),
        title_opts={"text": ""}
    )
)
exp_pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="239c2d875644445ea1fb6603b3c65f54" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_239c2d875644445ea1fb6603b3c65f54 = echarts.init(
#                     document.getElementById('239c2d875644445ea1fb6603b3c65f54'), 'white', {renderer: 'canvas'});
#                 var option_239c2d875644445ea1fb6603b3c65f54 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "1+x\u4e2d\u7ea7\u6570\u636e\u5206\u6790\u5e08",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5927\u6570\u636e\u5206\u6790\u5de5\u7a0b\u5e08",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5b9e\u4e60\u8bc1\u660e",
#                     "value": 1
#                 },
#                 {
#                     "name": "c1\u9a7e\u9a76\u8bc1",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5fae\u73ed\u7ea7\u8bc1\u4e66",
#                     "value": 12
#                 },
#                 {
#                     "name": "2019\u5b66\u5e74\u97e9\u5c71\u5e08\u8303\u5b66\u9662\u4e8c\u7b49\u5956\u5b66\u91d1",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6cf0\u8fea\u79d1\u6280\u5b9e\u4e60\u8bc1\u4e66",
#                     "value": 1
#                 },
#                 {
#                     "name": "2020\u5b66\u5e74\u97e9\u5c71\u5e08\u8303\u5b66\u9662\u4e00\u7b49\u5956\u5b66\u91d1",
#                     "value": 1
#                 },
#                 {
#                     "name": "2021\u5e74\u97e9\u5c71\u5e08\u8303\u5b66\u9662\u5b66\u751f\u4e13\u9879\u5956\u52b1\u4f18\u79c0\u5956",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790\u4e13\u4e1a\u6280\u80fd\u8bc1\u4e66",
#                     "value": 1
#                 },
#                 {
#                     "name": "2021\u5b66\u5e74\u97e9\u5c71\u5e08\u8303\u5b66\u9662\u4e00\u7b49\u5956\u5b66\u91d1",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8fbe\u68a6\u8ba4\u8bc1\u8bc1\u4e66",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6cf0\u8fea\u79d1\u6280\u5b9e\u4e60\u8bc1\u660e",
#                     "value": 326
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790\u5c31\u4e1a\u73ed\u4f53\u9a8c\u8425",
#                     "value": 1
#                 },
#                 {
#                     "name": "python\u6280\u672f\u5e94\u7528\u5de5\u7a0b\u5e08\uff08\u9ad8\u7ea7\uff09",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5168\u56fd\u8ba1\u7b97\u673a\u4e8c\u7ea7\u8003\u8bd5",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5927\u6570\u636e\u5f00\u53d1\u5de5\u7a0b\u5e08",
#                     "value": 1
#                 },
#                 {
#                     "name": "python\u6280\u672f\u5e94\u7528\u5de5\u7a0b\u5e08\uff08\u4e2d\u7ea7\uff09",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5168\u56fd\u5927\u5b66\u751f\u6570\u5b66\u5efa\u6a21\u7ade\u8d5b\u533a\u7ea7\u4e09\u7b49\u5956",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5e08\u8303\u751f\u4fe1\u606f\u5316\u6559\u5b66\u5e94\u7528\u5927\u8d5b\u5fae\u8bfe\u5236\u4f5c\u4e09\u7b49\u5956",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5168\u56fd\u8ba1\u7b97\u673amsoffice\u4e8c\u7ea7",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790\u5e08",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u82f1\u8bed\u56db\u7ea7",
#                     "value": 4
#                 },
#                 {
#                     "name": "cet4",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u9a7e\u9a76\u8bc1",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u666e\u901a\u8bdd\u6c34\u5e73\u7b49\u7ea7",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8ba1\u7b97\u673a\u4e8c\u7b49\u7ea7\u6c34\u5e73",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5927\u6570\u636e\u5e94\u7528\u5f00\u53d1(python)",
#                     "value": 2
#                 },
#                 {
#                     "name": "c1\u9a7e\u7167",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5927\u5b66\u82f1\u8bed\u56db\u7ea7",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u666e\u901a\u8bdd\u4e8c\u7ea7\u4e59\u7b49",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u56fd\u5bb6\u4fe1\u606f\u5b89\u5168\u6c34\u5e73\u6280\u672f\uff08\u4e00\u7ea7\uff09\u8bc1\u4e66",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u97e9\u5c71\u5e08\u8303\u5b66\u96622019\u5b66\u5e74\u5ea6\u201c\u4e09\u597d\u5b66\u751f\u201d\u79f0\u53f7\u8363\u8a89\u8bc1\u4e66",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5168\u56fd\u8ba1\u7b97\u673a\u7b49\u7ea7\u8003\u8bd5\u4e8c\u7ea7msoffice\u5408\u683c\u8bc1\u4e66",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u51c6\u9a7e\u8f66\u578b\u4e3ac1\u7684\u673a\u52a8\u8f66\u9a7e\u9a76\u8bc1",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u56fd\u5bb6\u4fe1\u606f\u5b89\u5168\u6c34\u5e73\u8bc1\u4e66\uff08\u4e00\u7ea7\uff09",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u666e\u901a\u8bdd\u6c34\u5e73\u6d4b\u8bd5\u7b49\u7ea7\u8bc1\u4e66",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5168\u56fd\u7edf\u8ba1\u4e13\u4e1a\u6280\u672f\u521d\u7ea7\u8d44\u683c\u8bc1\u4e66",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5168\u56fd\u4f1a\u8b

# %% [markdown]
# ### 工作经历

# %%
exp_counter = hunter_data.loc[:, ['工作经历']]
exp_counter_dict = {}
for idx in range(exp_counter.shape[0]):
    exp_types = eval(exp_counter.iloc[idx].values[0])
    if len(exp_types) == 0: continue
    # wage_count = social_counter.iloc[idx].values[1]
    for exp_type in exp_types:
        # if not isinstance(exp_type, str): continue
        exp_type = re.findall(r'\[(.*?)\]', exp_type)[0]
        if exp_type not in exp_counter_dict: 
            exp_counter_dict[exp_type] = 0
        exp_counter_dict[exp_type] += 1

len(exp_counter_dict)
# Out:
# 32

# %%
exp_pie = (
    Pie(init_opts=opts.InitOpts(width="800px", height="600px"))
    .add("", [list(z) for z in zip(list(exp_counter_dict.keys()), 
                                   exp_counter_dict.values())])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    .set_global_opts(
        legend_opts=opts.LegendOpts(is_show=False),
        toolbox_opts=opts.ToolboxOpts(is_show=True),
        title_opts={"text": ""}
    )
)
exp_pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c8b615b8dbd94deeb98021afb3fbdbf0" style="width:800px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c8b615b8dbd94deeb98021afb3fbdbf0 = echarts.init(
#                     document.getElementById('c8b615b8dbd94deeb98021afb3fbdbf0'), 'white', {renderer: 'canvas'});
#                 var option_c8b615b8dbd94deeb98021afb3fbdbf0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u52a9\u6559",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790\u5e08",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u5b9e\u4e60\u751f",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u524d\u7aef\u5f00\u53d1\u5b9e\u4e60",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u524d\u7aef\u5f00\u53d1",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5de5\u4f5c\u5ba4\u5ba4\u957f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8f85\u5bfc\u5458\u52a9\u7406",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4ea7\u54c1\u7ecf\u7406",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5b66\u79d1\u6559\u5e08",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5ba3\u4f20\u90e8\u526f\u90e8\u957f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u529e\u516c\u5ba4\u5b66\u751f\u52a9\u7406\u548c\u5b9e\u9a8c\u5ba4\u52a9\u7406",
#                     "value": 1
#                 },
#                 {
#                     "name": "etl\u5b9e\u4e60\u5f00\u53d1\u5de5\u7a0b\u5e08",
#                     "value": 1
#                 },
#                 {
#                     "name": "ETL\u5f00\u53d1\u5de5\u7a0b\u5e08",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6559\u5e08\u52a9\u7406",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5bb6\u5ead\u6559\u5e08",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5bb6\u6559\u8001\u5e08",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5bb6\u6559",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5730\u63a8\u5458",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u64cd\u4f5c\u5458",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4fe1\u606f\u7ba1\u7406\u5458",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8c03\u67e5\u5458",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790\u52a9\u7406",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u670d\u52a1\u5458",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4fe1\u606f\u91c7\u96c6\u5458",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790\u5e08\u52a9\u7406",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6570\u5b66\u6559\u5e08",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u884c\u653f\u524d\u53f0",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5bd2\u5047\u5de5",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5916\u4e1a\u4eba\u5458",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u884c\u653f\u52a9\u7406",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u521d\u4e2d\u6570\u5b66\u6559\u5e08",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4eba\u4e8b\u4e13\u5458\u5b9e\u4e60\u751f",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u52a9\u6559",
#                 "\u6570\u636e\u5206\u6790\u5e08",
#                 "\u5b9e\u4e60\u751f",
#                 "\u524d\u7aef\u5f00\u53d1\u5b9e\u4e60",
#                 "\u524d\u7aef\u5f00\u53d1",
#                 "\u5de5\u4f5c\u5ba4\u5ba4\u957f",
#                 "\u8f85\u5bfc\u5458\u52a9\u7406",
#                 "\u4ea7\u54c1\u7ecf\u7406",
#                 "\u5b66\u79d1\u6559\u5e08",
#                 "\u5ba3\u4f20\u90e8\u526f\u90e8\u957f",
#                 "\u529e\u516c\u5ba4\u5b66\u751f\u52a9\u7406\u548c\u5b9e\u9a8c\u5ba4\u52a9\u7406",
#                 "etl\u5b9e\u4e60\u5f00\u53d1\u5de5\u7a0b\u5e08",
#                 "ETL\u5f00\u53d1\u5de5\u7a0b\u5e08",
#                 "\u6559\u5e08\u52a9\u7406",
#                 "\u5bb6\u5ead\u6559\u5e08",
#                 "\u5bb6\u6559\u8001\u5e08",
#                 "\u5bb6\u6559",
#                 "\u5730\u63a8\u5458",
#                 "\u64cd\u4f5c\u5458",
#                 "\u4fe1\u606f\u7ba1\u7406\u5458",
#                 "\u8c03\u67e5\u5458",
#                 "\u6570\u636e\u5206\u6790\u52a9\u7406",
#                 "\u670d\u52a1\u5458",
#                 "\u4fe1\u606f\u91c7\u96c6\u545

# %% [markdown]
# ### 项目经历

# %%
exp_counter = hunter_data.loc[:, ['项目经历']]
exp_counter_dict = {}
for idx in range(exp_counter.shape[0]):
    exp_types = eval(exp_counter.iloc[idx].values[0])
    if len(exp_types) == 0: continue
    # wage_count = social_counter.iloc[idx].values[1]
    for exp_type in exp_types:
        # if not isinstance(exp_type, str): continue
        exp_type = re.findall(r'\[(.*?)\]', exp_type)[0]
        if exp_type not in exp_counter_dict: 
            exp_counter_dict[exp_type] = 0
        exp_counter_dict[exp_type] += 1

len(exp_counter_dict)
# Out:
# 59

# %%
exp_pie = (
    Pie(init_opts=opts.InitOpts(width="1200px", height="600px"))
    .add("", [list(z) for z in zip(list(exp_counter_dict.keys()), 
                                   exp_counter_dict.values())])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    .set_global_opts(
        legend_opts=opts.LegendOpts(is_show=False),
        toolbox_opts=opts.ToolboxOpts(is_show=True),
        title_opts={"text": ""}
    )
)
exp_pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="be3cbc9c18894da8bd37b56d4e57566c" style="width:1200px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_be3cbc9c18894da8bd37b56d4e57566c = echarts.init(
#                     document.getElementById('be3cbc9c18894da8bd37b56d4e57566c'), 'white', {renderer: 'canvas'});
#                 var option_be3cbc9c18894da8bd37b56d4e57566c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u6570\u636e\u5206\u6790",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u6838\u5fc3\u6210\u5458",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u6570\u636e\u5904\u7406\u5206\u6790\u4ee5\u53ca\u6a21\u578b\u6784\u5efa",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5b9e\u73b0\u6570\u636e\u5e93\u81ea\u52a8\u5316\u4ea4\u6613\u4fe1\u606f\u53d8\u66f4",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790\u5e08",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u8d1f\u8d23\u4eba",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u4e3b\u8981\u8d1f\u8d23\u4eba",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u552f\u4e00\u5b8c\u6210\u4eba",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4e3b\u8981\u5b8c\u6210\u4eba",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u9879\u76ee\u7ec4\u5c0f\u7ec4\u957f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u524d\u7aef\u5f00\u53d1",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u7ec4\u957f",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u5c0f\u7ec4\u961f\u957f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u961f\u957f",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u72ec\u7acb",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u6570\u636e\u5efa\u6a21",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8bba\u6587\u64b0\u5199\u548c\u8d44\u6599\u6536\u96c6",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u7f16\u5199\u524d\u7aef",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u524d\u540e\u7aef",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u524d\u540e\u7aef\u5f00\u53d1",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4e2a\u4eba\u5b9e\u8bad\u64cd\u4f5c",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u6210\u5458",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u8d1f\u8d23\u6570\u636e\u722c\u53d6\u6570\u636e\u4e0e\u5206\u6790",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8d1f\u8d23\u6570\u636e\u5efa\u6a21",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8d1f\u8d23\u56fe\u7247\u5904\u7406\u4e0e\u5efa\u6a21\u8c03\u4f18",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6570\u636e\u9884\u5904\u7406\u4e0e\u5efa\u6a21",
#                     "value": 1
#                 },
#                 {
#                     "name": "wed\u524d\u7aef\u8d1f\u8d23\u4eba",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u961f\u5458",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u6570\u636e\u5f00\u53d1\u7ec4\u7ec4\u5458",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4ee3\u7801\u7f16\u5199\u4ee5\u53ca\u8bba\u6587\u64b0\u5199",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u9879\u76ee\u8d1f\u8d23\u4eba",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u6570\u636e\u5e93\u5f00\u53d1",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u7ec4\u5458",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790\u5458",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6570\u636e\u6316\u6398",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4ee3\u7801\u5f00\u53d1\u8005",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4e3b\u8981\u6210\u5458",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5b66\u5458",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u4e2a\u4eba\u5b8c\u6210",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u7f16\u5199\u8bba\u6587",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4ee3\u7801\u8bba\u6587",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6784\u5efa\u57fa\u4e8e\u534f\u540c\u8fc7\u6ee4\u7b97\u6cd5\u7684\u6a21\u578b\u5411\u76ee\u6807\u7528\u6237\u5b9e\u73b0\u4e2a\u6027\u5316\u63a8\u8350",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u83b7\u53d6\u56fe\u50cf\u6570\u636e\u5e76\u8fdb\u884c\u56fe\u50cf\u5904\u7406\u5e76\u6784\u5efaCNN\u7f51\u7edc\u8fdb\u884c\u5b66\u4e60",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u9879\u76ee\u961f\u957f",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u53c2\u4e0e\u8005",

# %% [markdown]
# ### 培训经历

# %%
exp_counter = hunter_data.loc[:, ['培训经历']]
exp_counter_dict = {}
for idx in range(exp_counter.shape[0]):
    exp_types = eval(exp_counter.iloc[idx].values[0])
    if len(exp_types) == 0: continue
    # wage_count = social_counter.iloc[idx].values[1]
    for exp_type in exp_types:
        # if not isinstance(exp_type, str): continue
        exp_type = re.findall(r'\[(.*?)\]', exp_type)[0]
        if exp_type not in exp_counter_dict: 
            exp_counter_dict[exp_type] = 0
        exp_counter_dict[exp_type] += 1

len(exp_counter_dict)
# Out:
# 33

# %%
exp_pie = (
    Pie(init_opts=opts.InitOpts(width="800px", height="600px"))
    .add("", [list(z) for z in zip(list(exp_counter_dict.keys()), 
                                   exp_counter_dict.values())])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    .set_global_opts(
        legend_opts=opts.LegendOpts(is_show=False),
        toolbox_opts=opts.ToolboxOpts(is_show=True),
        title_opts={"text": ""}
    )
)
exp_pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4bec7015ae9c4addb68c7bc76fa96869" style="width:800px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4bec7015ae9c4addb68c7bc76fa96869 = echarts.init(
#                     document.getElementById('4bec7015ae9c4addb68c7bc76fa96869'), 'white', {renderer: 'canvas'});
#                 var option_4bec7015ae9c4addb68c7bc76fa96869 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u6570\u636e\u5206\u6790",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790\u5b9e\u8bad",
#                     "value": 2
#                 },
#                 {
#                     "name": "python\u6570\u636e\u6316\u6398",
#                     "value": 1
#                 },
#                 {
#                     "name": "python\u57f9\u8bad",
#                     "value": 1
#                 },
#                 {
#                     "name": "Python\u673a\u5668\u5b66\u4e60",
#                     "value": 1
#                 },
#                 {
#                     "name": "python\u8bfe\u7a0b\u57fa\u7840",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5927\u6570\u636e\u5e94\u7528\u5f00\u53d1",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5927\u6570\u636e\u5206\u6790\u4e0e\u6316\u6398",
#                     "value": 2
#                 },
#                 {
#                     "name": "powerbi",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790\u73ed",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5927\u6570\u636e\u5f00\u53d1",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u7f16\u7a0b\u8bed\u8a00",
#                     "value": 1
#                 },
#                 {
#                     "name": "python\u6570\u636e\u5206\u6790",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u6cf0\u8fea\u6570\u636e\u5f00\u53d1\u57f9\u8bad",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5927\u6570\u636e\u5f00\u53d1\u6280\u672f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790\u4e0e\u6316\u6398",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790\u6316\u6398",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5927\u6570\u636e\u5206\u6790",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u5927\u6570\u636e\u5206\u6790\u5c31\u4e1a\u73ed",
#                     "value": 1
#                 },
#                 {
#                     "name": "Python\u6570\u636e\u5206\u6790",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5927\u6570\u636e\u5f00\u53d1\u76f8\u5173\u8bfe\u7a0b",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6570\u636e\u5206\u6790\u548c\u6570\u636e\u6316\u6398",
#                     "value": 1
#                 },
#                 {
#                     "name": "Hadoop\u57fa\u7840",
#                     "value": 1
#                 },
#                 {
#                     "name": "Hive\u6570\u636e\u4ed3\u5e93",
#                     "value": 1
#                 },
#                 {
#                     "name": "HBase\u6570\u636e\u5e93",
#                     "value": 1
#                 },
#                 {
#                     "name": "Scala\u57fa\u7840",
#                     "value": 1
#                 },
#                 {
#                     "name": "Spark\u5927\u6570\u636e\u6280\u672f",
#                     "value": 1
#                 },
#                 {
#                     "name": "Flume\u6570\u636e\u91c7\u96c6",
#                     "value": 1
#                 },
#                 {
#                     "name": "Kafka\u6570\u636e\u6d41\u5904\u7406",
#                     "value": 1
#                 },
#                 {
#                     "name": "Flink\u5b9e\u65f6\u5904\u7406",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5206\u5e03\u5f0f\u6587\u4ef6\u641c\u7d22ES",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5927\u6570\u636e\u5f00\u53d1\u8bfe\u7a0b",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5927\u6570\u636e\u5f00\u53d1\u5de5\u7a0b\u5e08",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6570\u636e\u5206\u6790",
#                 "\u6570\u636e\u5206\u6790\u5b9e\u8bad",
#                 "python\u6570\u636e\u6316\u6398",
#                 "python\u57f9\u8bad",
#                 "Python\u673a\u5668\u5b66\u4e60",
#                 "python\u8bfe\u7a0b\u57fa\u7840",
#                 "\u5927\u6570\u636e\u5e94\u7528\u5f00\u53d1",
#                 "\u5927\u6570\u636e\u5206\u6790\u4e0e\u6316\u6398",
#                 "powerbi",
#                 "\u6570\u636e\u5206\u6790\u73ed",
#                 "\u5927\u6570\u636e\u5f00\u53d1",
#                 "\u7f16\u7a0b\u8bed\u8a00",
#                 "python\u6570\u636e\u5206\u6790",
#                 "\u6cf0\u8fea\u6570\u636e\u5f00\u53d1\u57f9\u8bad",
#                 "\u5927\u6570\u636e\u5f00\u53d1\u6280\u672f",
#                 "\u6570\u636e\u5206\u6790\u4e0e\u6316\u6398",

# %% [markdown]
# ### 学历

# %%
exp_counter = hunter_data.loc[:, ['教育经历']]
exp_counter_dict = {}
for idx in range(exp_counter.shape[0]):
    exp_types = eval(exp_counter.iloc[idx].values[0])
    if len(exp_types) == 0: continue
    # wage_count = social_counter.iloc[idx].values[1]
    edu_types = []
    for exp_type in exp_types:
        # if not isinstance(exp_type, str): continue
        exp_type = re.findall(r'\[(.*?)\]', exp_type)[0]
        edu_types.append(exp_type)
    if '硕士' in edu_types: exp_type = '硕士'
    elif '本科' in edu_types: exp_type = '本科'
    elif '大专' in edu_types: exp_type = '大专'
    if exp_type not in exp_counter_dict: 
        exp_counter_dict[exp_type] = 0
    exp_counter_dict[exp_type] += 1

exp_counter_dict
# Out:
# {'本科': 91, '硕士': 3, '大专': 2}

# %%
exp_pie = (
    Pie(init_opts=opts.InitOpts(width="1000px", height="600px"))
    .add("", [list(z) for z in zip(list(exp_counter_dict.keys()), 
                                   exp_counter_dict.values())])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    .set_global_opts(
        legend_opts=opts.LegendOpts(is_show=False),
        toolbox_opts=opts.ToolboxOpts(is_show=True),
        title_opts={"text": ""}
    )
)
exp_pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e178c4a970864473afc11eebe9544081" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e178c4a970864473afc11eebe9544081 = echarts.init(
#                     document.getElementById('e178c4a970864473afc11eebe9544081'), 'white', {renderer: 'canvas'});
#                 var option_e178c4a970864473afc11eebe9544081 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u672c\u79d1",
#                     "value": 91
#                 },
#                 {
#                     "name": "\u7855\u58eb",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5927\u4e13",
#                     "value": 2
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u672c\u79d1",
#                 "\u7855\u58eb",
#                 "\u5927\u4e13"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": {},
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",
#                     "\u5173\u95ed",
#                     "\u5237\u65b0"
#                 ],
#                 "backgroundColor": "#fff",
#                 "textareaColor": "#fff",
#                 "textareaBorderColor": "#333",
#                 "textColor": "#000",
#                 "buttonColor": "#c23531",
#                 "buttonTextColor": "#fff"
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u533a\u57df\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "icon": {},
#                 "filterMode": "filter"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u5207\u6362\u4e3a\u6298\u7ebf\u56fe",
#                     "bar": "\u5207\u6362\u4e3a\u67f1\u72b6\u56fe",
#                     "stack": "\u5207\u6362\u4e3a\u5806\u53e0",
#                     "tiled": "\u5207\u6362\u4e3a\u5e73\u94fa"
#                 },
#                 "icon": {}
#             }
#         }
#     }
# };
#                 chart_e178c4a970864473afc11eebe9544081.setOption(option_e178c4a970864473afc11eebe9544081);
#         });
#     </script>

# %% [markdown]
# ### 期望行业

# %%
pos_type_counter = hunter_data.loc[:, '期望行业'].values

pos_type_counter_dict = {}
for pos_types in pos_type_counter:
    for pos_type in eval(pos_types):
        if pos_type not in pos_type_counter_dict: 
            pos_type_counter_dict[pos_type] = 0
        pos_type_counter_dict[pos_type] += 1

len(pos_type_counter_dict)
# Out:
# 14

# %%
exp_pie = (
    Pie(init_opts=opts.InitOpts(width="800px", height="600px"))
    .add("", [list(z) for z in zip(list(pos_type_counter_dict.keys()), 
                                   pos_type_counter_dict.values())])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    .set_global_opts(
        legend_opts=opts.LegendOpts(is_show=False),
        toolbox_opts=opts.ToolboxOpts(is_show=True),
        title_opts={"text": ""}
    )
)
exp_pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9a8db8cb70ff432aa4e97202e6458d1a" style="width:800px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9a8db8cb70ff432aa4e97202e6458d1a = echarts.init(
#                     document.getElementById('9a8db8cb70ff432aa4e97202e6458d1a'), 'white', {renderer: 'canvas'});
#                 var option_9a8db8cb70ff432aa4e97202e6458d1a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u4e0d\u9650",
#                     "value": 75
#                 },
#                 {
#                     "name": "\u4e92\u8054\u7f51",
#                     "value": 8603
#                 },
#                 {
#                     "name": "\u6570\u636e\u670d\u52a1",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u7535\u5b50\u5546\u52a1",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u6e38\u620f",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u8ba1\u7b97\u673a\u8f6f\u4ef6",
#                     "value": 7
#                 },
#                 {
#                     "name": "O2O",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5a92\u4f53",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u91d1\u878d",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u5728\u7ebf\u6559\u80b2",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u4fe1\u606f\u5b89\u5168",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u533b\u7597\u5065\u5eb7",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u901a\u4fe1\u8bbe\u5907",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4eba\u529b\u8d44\u6e90\u670d\u52a1",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e0d\u9650",
#                 "\u4e92\u8054\u7f51",
#                 "\u6570\u636e\u670d\u52a1",
#                 "\u7535\u5b50\u5546\u52a1",
#                 "\u6e38\u620f",
#                 "\u8ba1\u7b97\u673a\u8f6f\u4ef6",
#                 "O2O",
#                 "\u5a92\u4f53",
#                 "\u91d1\u878d",
#                 "\u5728\u7ebf\u6559\u80b2",
#                 "\u4fe1\u606f\u5b89\u5168",
#                 "\u533b\u7597\u5065\u5eb7",
#                 "\u901a\u4fe1\u8bbe\u5907",
#                 "\u4eba\u529b\u8d44\u6e90\u670d\u52a1"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": {},
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",
#                     "\u5173\u95ed",
#                     "\u5237\u65b0"
#                 ],
#                 "backgroundColor": "#fff",
#                 "textareaColor": "#fff",
#                 "textareaBorderColor": "#333",
#                 "textColor": "#000",
#                 "buttonColor": "#c23531",
#                 "buttonTextColor": "#fff"
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u533a\u57df\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "icon": {},
#                 "filterMode": "filter"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],

# %% [markdown]
# ### 期望城市

# %%
addr_counter = hunter_data.loc[:, '期望城市']
addr_counter_dict = {}
for idx in range(addr_counter.shape[0]):
    # position_name = addr_counter.iloc[idx].values[0]
    position_addr = addr_counter.iloc[idx]
    if not isinstance(position_addr, str): continue
    # print(position_addr)
    position_addr = re.findall(r'(.*?(省|区|市))', position_addr)[0][0]
    if '广西壮族自治区' in position_addr: position_addr = '广西省'
    if position_addr not in addr_counter_dict: 
        addr_counter_dict[position_addr] = 0
    addr_counter_dict[position_addr] += 1
# edu_counter = job_data.loc[:, ['招聘岗位', '期望学历']]
 
addr_counter_dict
# Out:
# {'广东省': 138,
#  '重庆市': 2,
#  '湖北省': 2,
#  '广西省': 1,
#  '北京市': 5,
#  '天津市': 2,
#  '四川省': 1,
#  '湖南省': 1,
#  '辽宁省': 1,
#  '河北省': 1,
#  '陕西省': 1,
#  '山西省': 1}

# %%
c = (
    Geo(init_opts=opts.InitOpts(width="800px", height="600px"))
    .add_schema(maptype="china")
    .add("城市", 
         [list(z) for z in zip(
            list(addr_counter_dict.keys()), 
            list(addr_counter_dict.values()))],
            # type_=ChartType.HEATMAP,
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        toolbox_opts=opts.ToolboxOpts(is_show=True),
        title_opts=opts.TitleOpts(title="公司地点"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="3f26c0f3bc5d4e88b5b5a4e026d33599" style="width:800px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_3f26c0f3bc5d4e88b5b5a4e026d33599 = echarts.init(
#                     document.getElementById('3f26c0f3bc5d4e88b5b5a4e026d33599'), 'white', {renderer: 'canvas'});
#                 var option_3f26c0f3bc5d4e88b5b5a4e026d33599 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u57ce\u5e02",
#             "coordinateSystem": "geo",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c\u7701",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         138
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86\u5e02",
#                     "value": [
#                         106.55,
#                         29.57,
#                         2
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5317\u7701",
#                     "value": [
#                         114.341861,
#                         30.546498,
#                         2
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u897f\u7701",
#                     "value": [
#                         108.327546,
#                         22.815478,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": [
#                         116.4,
#                         39.9,
#                         5
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25\u5e02",
#                     "value": [
#                         117.2,
#                         39.12,
#                         2
#                     ]
#                 },
#                 {
#                     "name": "\u56db\u5ddd\u7701",
#                     "value": [
#                         104.075931,
#                         30.651651,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357\u7701",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u8fbd\u5b81\u7701",
#                     "value": [
#                         123.42944,
#                         41.835441,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u5317\u7701",
#                     "value": [
#                         114.468664,
#                         38.037057,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u9655\u897f\u7701",
#                     "value": [
#                         108.954239,
#                         34.265472,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "\u5c71\u897f\u7701",
#                     "value": [
#                         112.562398,
#                         37.873531,
#                         1
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u57ce\u5e02"
#             ],
#             "selected": {
#                 "\u57ce\u5e02": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u516c\u53f8\u5730\u70b9",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",
#                     "\u5173\u95ed",
#                     "\u5237\u65b0"
#                 ],
#                 "backgroundColor": "#fff",
#                 "textareaColor": "#fff",
#                 "textareaBorderColor": "#333",
#                 "textColor": "#000",
#                 "buttonColor": "#c23531",
#                 "buttonTextColor": "#fff"
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u533a\u57df\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "icon": {},
#                 "filterMode": "filter"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
